# %%
import community
import matplotlib.pyplot as plt
import networkx as nx

# %%
path=r"football.gml"
print(path)
Graph=nx.read_gml(path)
# Out:
# football.gml

# %%
#输出图信息
print(Graph.graph)
# Out:
# {}

# %%
#输出节点信息
print(Graph.nodes(data=True))
# Out:
# [('BrighamYoung', {'value': 7}), ('FloridaState', {'value': 0}), ('Iowa', {'value': 2}), ('KansasState', {'value': 3}), ('NewMexico', {'value': 7}), ('TexasTech', {'value': 3}), ('PennState', {'value': 2}), ('SouthernCalifornia', {'value': 8}), ('ArizonaState', {'value': 8}), ('SanDiegoState', {'value': 7}), ('Baylor', {'value': 3}), ('NorthTexas', {'value': 10}), ('NorthernIllinois', {'value': 6}), ('Northwestern', {'value': 2}), ('WesternMichigan', {'value': 6}), ('Wisconsin', {'value': 2}), ('Wyoming', {'value': 7}), ('Auburn', {'value': 9}), ('Akron', {'value': 6}), ('VirginiaTech', {'value': 1}), ('Alabama', {'value': 9}), ('UCLA', {'value': 8}), ('Arizona', {'value': 8}), ('Utah', {'value': 7}), ('ArkansasState', {'value': 10}), ('NorthCarolinaState', {'value': 0}), ('BallState', {'value': 6}), ('Florida', {'value': 9}), ('BoiseState', {'value': 11}), ('BostonCollege', {'value': 1}), ('WestVirginia', {'value': 1}), ('BowlingGreenState', {'value': 6}), ('Michigan', {'value': 2}), ('Virginia', {'value': 0}), ('Buffalo', {'value': 6}), ('Syracuse', {'value': 1}), ('CentralFlorida', {'value': 5}), ('GeorgiaTech', {'value': 0}), ('CentralMichigan', {'value': 6}), ('Purdue', {'value': 2}), ('Colorado', {'value': 3}), ('ColoradoState', {'value': 7}), ('Connecticut', {'value': 5}), ('EasternMichigan', {'value': 6}), ('EastCarolina', {'value': 4}), ('Duke', {'value': 0}), ('FresnoState', {'value': 11}), ('OhioState', {'value': 2}), ('Houston', {'value': 4}), ('Rice', {'value': 11}), ('Idaho', {'value': 10}), ('Washington', {'value': 8}), ('Kansas', {'value': 3}), ('SouthernMethodist', {'value': 11}), ('Kent', {'value': 6}), ('Pittsburgh', {'value': 1}), ('Kentucky', {'value': 9}), ('Louisville', {'value': 4}), ('LouisianaTech', {'value': 11}), ('LouisianaMonroe', {'value': 10}), ('Minnesota', {'value': 2}), ('MiamiOhio', {'value': 6}), ('Vanderbilt', {'value': 9}), ('MiddleTennesseeState', {'value': 10}), ('Illinois', {'value': 2}), ('MississippiState', {'value': 9}), ('Memphis', {'value': 4}), ('Nevada', {'value': 11}), ('Oregon', {'value': 8}), ('NewMexicoState', {'value': 10}), ('SouthCarolina', {'value': 9}), ('Ohio', {'value': 6}), ('IowaState', {'value': 3}), ('SanJoseState', {'value': 11}), ('Nebraska', {'value': 3}), ('SouthernMississippi', {'value': 4}), ('Tennessee', {'value': 9}), ('Stanford', {'value': 8}), ('WashingtonState', {'value': 8}), ('Temple', {'value': 1}), ('Navy', {'value': 5}), ('TexasA&M', {'value': 3}), ('NotreDame', {'value': 5}), ('TexasElPaso', {'value': 11}), ('Oklahoma', {'value': 3}), ('Toledo', {'value': 6}), ('Tulane', {'value': 4}), ('Mississippi', {'value': 9}), ('Tulsa', {'value': 11}), ('NorthCarolina', {'value': 0}), ('UtahState', {'value': 5}), ('Army', {'value': 4}), ('Cincinnati', {'value': 4}), ('AirForce', {'value': 7}), ('Rutgers', {'value': 1}), ('Georgia', {'value': 9}), ('LouisianaState', {'value': 9}), ('LouisianaLafayette', {'value': 10}), ('Texas', {'value': 3}), ('Marshall', {'value': 6}), ('MichiganState', {'value': 2}), ('MiamiFlorida', {'value': 1}), ('Missouri', {'value': 3}), ('Clemson', {'value': 0}), ('NevadaLasVegas', {'value': 7}), ('WakeForest', {'value': 0}), ('Indiana', {'value': 2}), ('OklahomaState', {'value': 3}), ('OregonState', {'value': 8}), ('Maryland', {'value': 0}), ('TexasChristian', {'value': 4}), ('California', {'value': 8}), ('AlabamaBirmingham', {'value': 4}), ('Arkansas', {'value': 9}), ('Hawaii', {'value': 11})]

# %%
#输出边信息
print(Graph.edges())
#计算图或网络的传递性
print(nx.transitivity(Graph))
#节点个数
print(Graph.number_of_nodes())
#边数
print(Graph.number_of_edges())
#节点邻居的个数
print(Graph.neighbors(1))
# Out:
# [('BrighamYoung', 'FloridaState'), ('BrighamYoung', 'NewMexico'), ('BrighamYoung', 'SanDiegoState'), ('BrighamYoung', 'Wyoming'), ('BrighamYoung', 'Utah'), ('BrighamYoung', 'Virginia'), ('BrighamYoung', 'Syracuse'), ('BrighamYoung', 'ColoradoState'), ('BrighamYoung', 'MississippiState'), ('BrighamYoung', 'UtahState'), ('BrighamYoung', 'AirForce'), ('BrighamYoung', 'NevadaLasVegas'), ('FloridaState', 'NorthCarolinaState'), ('FloridaState', 'Florida'), ('FloridaState', 'Virginia'), ('FloridaState', 'GeorgiaTech'), ('FloridaState', 'Duke'), ('FloridaState', 'Louisville'), ('FloridaState', 'NorthCarolina'), ('FloridaState', 'MiamiFlorida'), ('FloridaState', 'Clemson'), ('FloridaState', 'WakeForest'), ('FloridaState', 'Maryland'), ('Iowa', 'KansasState'), ('Iowa', 'PennState'), ('Iowa', 'Northwestern'), ('Iowa', 'WesternMichigan'), ('Iowa', 'Wisconsin'), ('Iowa', 'OhioState'), ('Iowa', 'Minnesota'), ('Iowa', 'Illinois'), ('Iowa', 'IowaState'), ('Iowa', 'Nebraska'), ('Iowa', 'MichiganState'), ('Iowa', 'Indiana'), ('KansasState', 'TexasTech'), ('KansasState', 'NorthTexas'), ('KansasState', 'BallState'), ('KansasState', 'Colorado'), ('KansasState', 'Kansas'), ('KansasState', 'LouisianaTech'), ('KansasState', 'IowaState'), ('KansasState', 'Nebraska'), ('KansasState', 'TexasA&M'), ('KansasState', 'Oklahoma'), ('KansasState', 'Missouri'), ('NewMexico', 'TexasTech'), ('NewMexico', 'SanDiegoState'), ('NewMexico', 'Wyoming'), ('NewMexico', 'Utah'), ('NewMexico', 'BoiseState'), ('NewMexico', 'ColoradoState'), ('NewMexico', 'NewMexicoState'), ('NewMexico', 'AirForce'), ('NewMexico', 'NevadaLasVegas'), ('NewMexico', 'OregonState'), ('TexasTech', 'Baylor'), ('TexasTech', 'NorthTexas'), ('TexasTech', 'Kansas'), ('TexasTech', 'Nebraska'), ('TexasTech', 'TexasA&M'), ('TexasTech', 'Oklahoma'), ('TexasTech', 'UtahState'), ('TexasTech', 'LouisianaLafayette'), ('TexasTech', 'Texas'), ('TexasTech', 'OklahomaState'), ('PennState', 'SouthernCalifornia'), ('PennState', 'Michigan'), ('PennState', 'Purdue'), ('PennState', 'OhioState'), ('PennState', 'Pittsburgh'), ('PennState', 'LouisianaTech'), ('PennState', 'Minnesota'), ('PennState', 'Illinois'), ('PennState', 'Toledo'), ('PennState', 'MichiganState'), ('PennState', 'Indiana'), ('SouthernCalifornia', 'ArizonaState'), ('SouthernCalifornia', 'UCLA'), ('SouthernCalifornia', 'Arizona'), ('SouthernCalifornia', 'Colorado'), ('SouthernCalifornia', 'Oregon'), ('SouthernCalifornia', 'SanJoseState'), ('SouthernCalifornia', 'Stanford'), ('SouthernCalifornia', 'WashingtonState'), ('SouthernCalifornia', 'NotreDame'), ('SouthernCalifornia', 'OregonState'), ('SouthernCalifornia', 'California'), ('ArizonaState', 'SanDiegoState'), ('ArizonaState', 'UCLA'), ('ArizonaState', 'Arizona'), ('ArizonaState', 'ColoradoState'), ('ArizonaState', 'Washington'), ('ArizonaState', 'Oregon'), ('ArizonaState', 'Stanford'), ('ArizonaState', 'WashingtonState'), ('ArizonaState', 'UtahState'), ('ArizonaState', 'California'), ('SanDiegoState', 'Wyoming'), ('SanDiegoState', 'Arizona'), ('SanDiegoState', 'Utah'), ('SanDiegoState', 'ColoradoState'), ('SanDiegoState', 'Illinois'), ('SanDiegoState', 'AirForce'), ('SanDiegoState', 'NevadaLasVegas'), ('SanDiegoState', 'OregonState'), ('Baylor', 'NorthTexas'), ('Baylor', 'Minnesota'), ('Baylor', 'IowaState'), ('Baylor', 'Nebraska'), ('Baylor', 'TexasA&M'), ('Baylor', 'Oklahoma'), ('Baylor', 'Texas'), ('Baylor', 'Missouri'), ('Baylor', 'OklahomaState'), ('NorthTexas', 'ArkansasState'), ('NorthTexas', 'BoiseState'), ('NorthTexas', 'Idaho'), ('NorthTexas', 'NewMexicoState'), ('NorthTexas', 'UtahState'), ('NorthTexas', 'LouisianaLafayette'), ('NorthTexas', 'NevadaLasVegas'), ('NorthernIllinois', 'Northwestern'), ('NorthernIllinois', 'WesternMichigan'), ('NorthernIllinois', 'Auburn'), ('NorthernIllinois', 'Akron'), ('NorthernIllinois', 'BallState'), ('NorthernIllinois', 'Buffalo'), ('NorthernIllinois', 'CentralFlorida'), ('NorthernIllinois', 'CentralMichigan'), ('NorthernIllinois', 'EasternMichigan'), (' ...
# 0.4072398190045249
# 115
# 613
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\classes\graph.py in neighbors(self, n)
#    1127         try:
# -> 1128             return iter(self._adj[n])
#    1129         except KeyError:
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-24-12163d8a2a42> in <module>()
#       8 print(Graph.number_of_edges())
#       9 #节点邻居的个数
# ---> 10 print(Graph.neighbors(1))
#      11 # 图划分
#      12 part = community.best_partition(Graph)
#
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\classes\graph.py in neighbors(self, n)
#    1128             return iter(self._adj[n])
#    1129         except KeyError:
# -> 1130             raise NetworkXError("The node %s is not in the graph." % (n,))
#    1131
#    1132     @property
#
# NetworkXError: The node 1 is not in the graph.

# %%
# 图划分
part = community.best_partition(G)
print(part)
# Out:
# {'BrighamYoung': 0, 'FloridaState': 1, 'Iowa': 2, 'KansasState': 3, 'NewMexico': 0, 'TexasTech': 3, 'PennState': 2, 'SouthernCalifornia': 4, 'ArizonaState': 4, 'SanDiegoState': 0, 'Baylor': 3, 'NorthTexas': 0, 'NorthernIllinois': 5, 'Northwestern': 2, 'WesternMichigan': 5, 'Wisconsin': 2, 'Wyoming': 0, 'Auburn': 6, 'Akron': 5, 'VirginiaTech': 7, 'Alabama': 6, 'UCLA': 4, 'Arizona': 4, 'Utah': 0, 'ArkansasState': 0, 'NorthCarolinaState': 1, 'BallState': 5, 'Florida': 6, 'BoiseState': 0, 'BostonCollege': 7, 'WestVirginia': 7, 'BowlingGreenState': 5, 'Michigan': 2, 'Virginia': 1, 'Buffalo': 5, 'Syracuse': 7, 'CentralFlorida': 6, 'GeorgiaTech': 1, 'CentralMichigan': 5, 'Purdue': 2, 'Colorado': 3, 'ColoradoState': 0, 'Connecticut': 5, 'EasternMichigan': 5, 'EastCarolina': 8, 'Duke': 1, 'FresnoState': 9, 'OhioState': 2, 'Houston': 8, 'Rice': 9, 'Idaho': 0, 'Washington': 4, 'Kansas': 3, 'SouthernMethodist': 9, 'Kent': 5, 'Pittsburgh': 7, 'Kentucky': 6, 'Louisville': 8, 'LouisianaTech': 6, 'LouisianaMonroe': 6, 'Minnesota': 2, 'MiamiOhio': 5, 'Vanderbilt': 6, 'MiddleTennesseeState': 6, 'Illinois': 2, 'MississippiState': 6, 'Memphis': 8, 'Nevada': 9, 'Oregon': 4, 'NewMexicoState': 0, 'SouthCarolina': 6, 'Ohio': 5, 'IowaState': 3, 'SanJoseState': 9, 'Nebraska': 3, 'SouthernMississippi': 8, 'Tennessee': 6, 'Stanford': 4, 'WashingtonState': 4, 'Temple': 7, 'Navy': 7, 'TexasA&M': 3, 'NotreDame': 7, 'TexasElPaso': 9, 'Oklahoma': 3, 'Toledo': 5, 'Tulane': 8, 'Mississippi': 6, 'Tulsa': 9, 'NorthCarolina': 1, 'UtahState': 0, 'Army': 8, 'Cincinnati': 8, 'AirForce': 0, 'Rutgers': 7, 'Georgia': 6, 'LouisianaState': 6, 'LouisianaLafayette': 6, 'Texas': 3, 'Marshall': 5, 'MichiganState': 2, 'MiamiFlorida': 7, 'Missouri': 3, 'Clemson': 1, 'NevadaLasVegas': 0, 'WakeForest': 1, 'Indiana': 2, 'OklahomaState': 3, 'OregonState': 4, 'Maryland': 1, 'TexasChristian': 9, 'California': 4, 'AlabamaBirmingham': 8, 'Arkansas': 6, 'Hawaii': 9}

# %%
#计算模块度
mod = community.modularity(part,Graph)
print(mod)
# Out:
# 0.6043460210927457

# %%
plt.figure(figsize=(30,20))
#绘图
values = [part.get(node) for node in Graph.nodes()]
nx.draw_spring(Graph, cmap=plt.get_cmap('jet'), node_color = values, node_size=30, with_labels=True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
