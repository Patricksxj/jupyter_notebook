# %%
import json

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Documents\\jupyter notebook\\车牌json转换'

# %%
with open("CarPrefix.json", 'r',encoding='utf-8') as f:
    temp = json.loads(f.read())

# %%
temp
# Out:
# [{'Pcode': 'HB', 'city': '石家庄', 'code': '冀A', 'province': '河北'},
#  {'Pcode': 'HB', 'city': '唐山', 'code': '冀B', 'province': '河北'},
#  {'Pcode': 'HB', 'city': '秦皇岛', 'code': '冀C', 'province': '河北'},
#  {'Pcode': 'HB', 'city': '邯郸', 'code': '冀D', 'province': '河北'},
#  {'Pcode': 'HB', 'city': '邢台', 'code': '冀E', 'province': '河北'},
#  {'Pcode': 'HB', 'city': '保定', 'code': '冀F', 'province': '河北'},
#  {'Pcode': 'HB', 'city': '张家口', 'code': '冀G', 'province': '河北'},
#  {'Pcode': 'HB', 'city': '承德', 'code': '冀H', 'province': '河北'},
#  {'Pcode': 'HB', 'city': '沧州', 'code': '冀J', 'province': '河北'},
#  {'Pcode': 'HB', 'city': '廊坊', 'code': '冀R', 'province': '河北'},
#  {'Pcode': 'HB', 'city': '沧州', 'code': '冀S', 'province': '河北'},
#  {'Pcode': 'HB', 'city': '衡水', 'code': '冀T', 'province': '河北'},
#  {'Pcode': 'LN', 'city': '沈阳', 'code': '辽A', 'province': '辽宁'},
#  {'Pcode': 'LN', 'city': '大连', 'code': '辽B', 'province': '辽宁'},
#  {'Pcode': 'LN', 'city': '鞍山', 'code': '辽C', 'province': '辽宁'},
# ...

# %%
import pandas as pd
df=pd.DataFrame(temp,columns=['Pcode','city','code','province'])

# %%
df.to_excel('车牌对应省市.xls')
