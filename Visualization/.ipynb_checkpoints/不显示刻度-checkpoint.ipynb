# %%
from sklearn.datasets import fetch_olivetti_faces
import matplotlib.pyplot as plt

faces = fetch_olivetti_faces().images
fig, ax = plt.subplots(5, 5, figsize=(15, 15))
fig.subplots_adjust(hspace=0, wspace=0) 

for i in range(5):
    for j in range(5):
        ax[i, j].xaxis.set_major_locator(plt.NullLocator())
        ax[i, j].yaxis.set_major_locator(plt.NullLocator())
        ax[i, j].imshow(faces[10*i+j], cmap='bone')

# %%
faces[10]
# Out:
# array([[0.5413223 , 0.58677685, 0.6404959 , ..., 0.54545456, 0.553719  ,
#         0.55785125],
#        [0.553719  , 0.61570245, 0.6570248 , ..., 0.57438016, 0.58264464,
#         0.5785124 ],
#        [0.5785124 , 0.6528926 , 0.677686  , ..., 0.57024795, 0.60330576,
#         0.59917355],
#        ...,
#        [0.12809917, 0.13636364, 0.13636364, ..., 0.09090909, 0.11570248,
#         0.10743801],
#        [0.1322314 , 0.13636364, 0.1322314 , ..., 0.09504132, 0.11157025,
#         0.10743801],
#        [0.13636364, 0.1322314 , 0.13636364, ..., 0.09504132, 0.11157025,
#         0.11157025]], dtype=float32)
