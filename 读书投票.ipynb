# %%
import re
import requests
from requests import RequestException
import time
import json
import socket
import random

# %%
def get_page(url):
	try:
		headers = {
			'Referer': 'https://form-preview-api.eqxiu.com',  # 伪装
			'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.87 Safari/537.36'  # 伪装成浏览器
		}
		response = requests.get(url, headers=headers)
		return None

	except RequestException:
		print(' 请求出错')
		return None

def vote(url, n):
	ip = [i for i in range(1,256)]
	Fake_Ip = '{}.{}.{}.{}'.format(random.choice(ip),random.choice(ip),random.choice(ip),random.choice(ip))
	print('Fake_Ip: {}'.format(Fake_Ip))
	datas ={'eq[f_vote_7838163172]': '5','costTime': random.randrange(300000,400000),'fromDetail':'', 'eq[f_va_random]': '100d472ca05f421ebb4c86732aa80106','eq[f_va_code]': '280242a7a751af4ded759cf12e86d78b'}
	header = {
		'Accept': '*/*',
		'Accept-Encoding': 'gzip, deflate, br',
		'Accept-Language': 'en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7,zh-TW;q=0.6',
		'Content-Length': '160',
		'Content-Type': 'application/x-www-form-urlencoded',
		'Origin': 'https://h5.ebdan.net',
		'Proxy-Connection': 'keep-alive',
		'Referer': 'https://h5.ebdan.net',
		'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.87 Safari/537.36',
		'X-Requested-With': 'XMLHttpRequest',
		'X-Real-Ip':Fake_Ip,
		'X-Forwarded-For':Fake_Ip,
		'cookie':'ARK_STARTUP=eyJTVEFSVFVQIjp0cnVlLCJTVEFSVFVQVElNRSI6IjIwMjAtMDctMTkgMTQ6MjY6NTcuOTY5In0%3D; ARK_ID=JS6be08bde67334baaf12bf40d6b20812b6be0; FZ_STROAGE.eqxiu.com=...%3D; _tracker_distinct_id_=202007194f62e7fa; _tracker_session_id_=b4c7884a-bed7-4543-8ed0-d6540f3a3cdf; _tracker_launch_=1' }
	for i in range(n):           
		response = requests.post(url, headers=header, data=datas)
		resp = response.status_code
		#print(response.content)
		print("result=",resp,',+1票,14号加油！！')
		print('\n\n')
def main():
	url = 'https://h5.ebdan.net/ls/RMQVuwS2#submit#submit#submit'  # 网页浏览的 url
	url2 = 'https://form-preview-api.eqxiu.com/lp/r/9162029/5320394053?code=RMQVuwS2'  # 待刷票数的 url
	for i in range(30):
		sleep_time=random.randrange(1,2)
		time.sleep(sleep_time)
		print('sleep_time:',sleep_time)
		vote(url2,10)
		#get_page (url) #浏览网页


if __name__ == '__main__':
	main()
# Out:
# sleep_time: 1
# Fake_Ip: 201.244.101.41
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# sleep_time: 1
# Fake_Ip: 212.233.25.157
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# sleep_time: 1
# Fake_Ip: 117.57.36.104
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# result= 200 ,+1票,14号加油！！
#
#
#
# ...

# %%
url2 = 'https://form-preview-api.eqxiu.com/lp/r/9162029/5320394053?code=RMQVuwS2' 
print(url2)
# Out:
# https://form-preview-api.eqxiu.com/lp/r/9162029/5320394053?code=RMQVuwS2

# %%
datas ={'f_vote_7838163172': '42','costTime': '328622','fromDetail':'', 'f_va_random': '100d472ca05f421ebb4c86732aa80106','f_va_code': '280242a7a751af4ded759cf12e86d78b'}
print(datas)
# Out:
# {'f_vote_7838163172': '42', 'costTime': '328622', 'fromDetail': '', 'f_va_random': '100d472ca05f421ebb4c86732aa80106', 'f_va_code': '280242a7a751af4ded759cf12e86d78b'}

# %%
response = requests.post(url2, headers=header, data=datas)

# %%
a=time.sleep(random.randrange(1,5.0))
print(a)
# Out:
# None

# %%
import random

# %%
random.randrange(1,5.0)
# Out:
# 4
